# %% [markdown]
# ## [참고 사이트](https://velog.io/@parkmj9453/%EB%8D%B0%EC%9D%B4%ED%84%B0-%EC%8B%9C%EA%B0%81%ED%99%94-%EB%8F%84%EA%B5%AC-seaborn)

# %%
# Import seaborn
import seaborn as sns

# Apply the default theme
sns.set_theme()

# Load an example dataset
tips = sns.load_dataset("tips")

# Create a visualization
sns.relplot(
    data=tips,
    x="total_bill", y="tip", col="time",
    hue="smoker", style="smoker", size="size",
)

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
tips[tips['size']==6]
# Out:
#      total_bill  tip     sex smoker   day    time  size
# 125       29.80  4.2  Female     No  Thur   Lunch     6
# 141       34.30  6.7    Male     No  Thur   Lunch     6
# 143       27.05  5.0  Female     No  Thur   Lunch     6
# 156       48.17  5.0    Male     No   Sun  Dinner     6

# %%
sns.scatterplot(
    data=tips,
    x="total_bill", y="tip", 
    hue="smoker", style="smoker", size="size",
)
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
sns.scatterplot(
    data=tips,
    x="total_bill", y="tip", 
    hue="smoker", style="time", size="size",
)
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
sns.relplot(
    data=tips,
    x="total_bill", y="tip", 
    hue="smoker", style="time", size="size",
);

# %%
tips[tips['size'] == 6]
# Out:
#      total_bill  tip     sex smoker   day    time  size
# 125       29.80  4.2  Female     No  Thur   Lunch     6
# 141       34.30  6.7    Male     No  Thur   Lunch     6
# 143       27.05  5.0  Female     No  Thur   Lunch     6
# 156       48.17  5.0    Male     No   Sun  Dinner     6

# %%
tips[tips['total_bill'] >= 46]
# Out:
#      total_bill    tip   sex smoker  day    time  size
# 59        48.27   6.73  Male     No  Sat  Dinner     4
# 156       48.17   5.00  Male     No  Sun  Dinner     6
# 170       50.81  10.00  Male    Yes  Sat  Dinner     3
# 212       48.33   9.00  Male     No  Sat  Dinner     4

# %% [markdown]
# ## data dots

# %%
dots = sns.load_dataset("dots")
sns.relplot(
    data=dots, kind="line",
    x="time", y="firing_rate", col="align",
    hue="choice", size="coherence", style="choice",
    facet_kws=dict(sharex=False),
)

# %%
dots.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 848 entries, 0 to 847
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   align        848 non-null    object
#  1   choice       848 non-null    object
#  2   time         848 non-null    int64
#  3   coherence    848 non-null    float64
#  4   firing_rate  848 non-null    float64
# dtypes: float64(2), int64(1), object(2)
# memory usage: 33.3+ KB

# %%
dots.head()
# Out:
#   align choice  time  coherence  firing_rate
# 0  dots     T1   -80        0.0    33.189967
# 1  dots     T1   -80        3.2    31.691726
# 2  dots     T1   -80        6.4    34.279840
# 3  dots     T1   -80       12.8    32.631874
# 4  dots     T1   -80       25.6    35.060487

# %%
dots.value_counts()
# Out:
# align  choice  time  coherence  firing_rate
# dots   T1      -80   0.0        33.189967      1
# sacc   T1       100  51.2       37.744141      1
#                 120  3.2        29.985119      1
#                      6.4        30.867971      1
#                      12.8       29.629630      1
#                                               ..
# dots   T2       220  3.2        45.341718      1
#                      6.4        45.400059      1
#                      12.8       41.856553      1
#                      25.6       42.423455      1
# sacc   T2       300  51.2       30.959302      1
# Length: 848, dtype: int64

# %%
dots['align'].value_counts()
# Out:
# sacc    454
# dots    394
# Name: align, dtype: int64

# %%
dots['choice'].value_counts()
# Out:
# T2    430
# T1    418
# Name: choice, dtype: int64

# %%
dots['time'].value_counts()
# Out:
# -80     24
#  120    24
#  280    24
#  260    24
#  240    24
#         ..
#  660     4
# -580     3
# -600     3
#  720     3
#  700     3
# Name: time, Length: 67, dtype: int64

# %%
dots['coherence'].value_counts()
# Out:
# 0.0     174
# 3.2     170
# 6.4     156
# 12.8    142
# 25.6    116
# 51.2     90
# Name: coherence, dtype: int64
