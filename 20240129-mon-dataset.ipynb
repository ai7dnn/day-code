# %% [markdown]
# ## [seaborn 참고 사이트](https://dining-developer.tistory.com/30)

# %%
from pydataset import data
data()
# Out:
#         dataset_id                                             title
# 0    AirPassengers       Monthly Airline Passenger Numbers 1949-1960
# 1          BJsales                 Sales Data with Leading Indicator
# 2              BOD                         Biochemical Oxygen Demand
# 3     Formaldehyde                     Determination of Formaldehyde
# 4     HairEyeColor         Hair and Eye Color of Statistics Students
# ..             ...                                               ...
# 752        VerbAgg                  Verbal Aggression item responses
# 753           cake                 Breakage Angle of Chocolate Cakes
# 754           cbpp                 Contagious bovine pleuropneumonia
# 755    grouseticks  Data on red grouse ticks from Elston et al. 2001
# 756     sleepstudy       Reaction times in a sleep deprivation study
#
# [757 rows x 2 columns]

# %%
data('AirPassengers', show_doc=True)
# Out:
# AirPassengers
#
# PyDataset Documentation (adopted from R Documentation. The displayed examples are in R)
#
# ## Monthly Airline Passenger Numbers 1949-1960
#
# ### Description
#
# The classic Box & Jenkins airline data. Monthly totals of international
# airline passengers, 1949 to 1960.
#
# ### Usage
#
#     AirPassengers
#
# ### Format
#
# A monthly time series, in thousands.
#
# ### Source
#
# Box, G. E. P., Jenkins, G. M. and Reinsel, G. C. (1976) _Time Series Analysis,
# Forecasting and Control._ Third Edition. Holden-Day. Series G.
#
# ### Examples
#
#     ## Not run:
#     ## These are quite slow and so not run by example(AirPassengers)
#     ## The classic 'airline model', by full ML
#     (fit <- arima(log10(AirPassengers), c(0, 1, 1),
#                   seasonal = list(order = c(0, 1, 1), period = 12)))
#     update(fit, method = "CSS")
#     update(fit, x = window(log10(AirPassengers), start = 1954))
#     pred <- predict(fit, n.ahead = 24)
# ...

# %%
air = data('AirPassengers')
air
# Out:
#             time  AirPassengers
# 1    1949.000000            112
# 2    1949.083333            118
# 3    1949.166667            132
# 4    1949.250000            129
# 5    1949.333333            121
# 6    1949.416667            135
# 7    1949.500000            148
# 8    1949.583333            148
# 9    1949.666667            136
# 10   1949.750000            119
# 11   1949.833333            104
# 12   1949.916667            118
# 13   1950.000000            115
# 14   1950.083333            126
# 15   1950.166667            141
# 16   1950.250000            135
# 17   1950.333333            125
# 18   1950.416667            149
# 19   1950.500000            170
# 20   1950.583333            170
# 21   1950.666667            158
# 22   1950.750000            133
# 23   1950.833333            114
# 24   1950.916667            140
# 25   1951.000000            145
# 26   1951.083333            150
# 27   1951.166667            178
# 28   1951.250000            163
# ...

# %%
tt = data('titanic')
tt.head()
# Out:
#        class     age  sex survived
# 1  1st class  adults  man      yes
# 2  1st class  adults  man      yes
# 3  1st class  adults  man      yes
# 4  1st class  adults  man      yes
# 5  1st class  adults  man      yes

# %%
import seaborn as sns
sns.countplot(x='sex', data=tt);

# %%
import seaborn as sns
sns.countplot(x='sex', hue='survived', data=tt);

# %%
import seaborn as sns
sns.countplot(x='sex', hue='survived', data=tt, palette='YlGnBu');

# %%
import seaborn as sns
sns.countplot(x='class', hue='survived', data=tt, palette='YlGnBu');

# %%
import seaborn as sns
ttdf = sns.load_dataset('titanic')
ttdf
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
ttdf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    int64
#  1   pclass       891 non-null    int64
#  2   sex          891 non-null    object
#  3   age          714 non-null    float64
#  4   sibsp        891 non-null    int64
#  5   parch        891 non-null    int64
#  6   fare         891 non-null    float64
#  7   embarked     889 non-null    object
#  8   class        891 non-null    category
#  9   who          891 non-null    object
#  10  adult_male   891 non-null    bool
#  11  deck         203 non-null    category
#  12  embark_town  889 non-null    object
#  13  alive        891 non-null    object
#  14  alone        891 non-null    bool
# dtypes: bool(2), category(2), float64(2), int64(4), object(5)
# memory usage: 80.7+ KB

# %%
sns.countplot(x='embarked', hue='survived', data=ttdf, palette='YlGnBu');

# %%
sns.countplot(x='embark_town', hue='class', data=ttdf, palette='GnBu');

# %%
sns.countplot(x='embark_town', hue='alone', data=ttdf, palette='GnBu');

# %%
tips = sns.load_dataset('tips')
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
tips.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  244 non-null    float64
#  1   tip         244 non-null    float64
#  2   sex         244 non-null    category
#  3   smoker      244 non-null    category
#  4   day         244 non-null    category
#  5   time        244 non-null    category
#  6   size        244 non-null    int64
# dtypes: category(4), float64(2), int64(1)
# memory usage: 7.4 KB

# %%
sns.countplot(x='day', hue='sex', data=tips, palette='twilight');

# %%
sns.countplot(x='time', hue='day', data=tips, palette='viridis');

# %%
sns.countplot(x='sex', hue='smoker', data=tips, palette='winter');

# %%
sns.countplot(x='size', hue='smoker', data=tips, palette='vlag');

# %%
sns.histplot(x=tips['total_bill']);

# %%
sns.histplot(x=tips.tip);

# %%
sns.histplot(x=tips['total_bill'], y=tips['tip'])
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
sns.kdeplot(x=tips['total_bill']);

# %%
sns.displot(x=tips['total_bill'], kind='kde');

# %%
sns.kdeplot(x=tips['total_bill'], y=tips['tip']);

# %%
sns.displot(x=tips['total_bill'], y=tips['tip'], kind='kde');

# %%
sns.ecdfplot(x=tips['total_bill']);

# %%
sns.displot(x=tips['total_bill'], kind='ecdf');

# %%
sns.kdeplot(x=tips["total_bill"])
sns.rugplot(x=tips["total_bill"]);

# %%
sns.barplot(x = tips['sex'], y = tips['tip']);

# %%
sns.countplot(x = tips['sex']);

# %%
sns.boxplot(x = tips['total_bill']);

# %%
sns.boxplot(y = tips['total_bill'], x = tips['smoker'])
# Out:
# <Axes: xlabel='smoker', ylabel='total_bill'>

# %%
sns.boxplot(y = tips['total_bill'], x = tips['size'])
# Out:
# <Axes: xlabel='size', ylabel='total_bill'>

# %%
sns.violinplot(y = tips['total_bill'], x = tips['smoker']);

# %%
sns.boxplot(y = tips['total_bill'], x = tips['size'])
# Out:
# <Axes: xlabel='size', ylabel='total_bill'>

# %%
sns.stripplot(y = tips['total_bill'], x = tips['smoker']);

# %%
sns.stripplot(y = tips['total_bill'], x = tips['size']);

# %%
sns.swarmplot(y = tips['total_bill'], x = tips['smoker']);

# %%
import warnings
warnings.filterwarnings(action='ignore')

# %%
sns.swarmplot(y = tips['total_bill'], x = tips['size']);

# %%
tips.corr()
# Out:
#             total_bill       tip      size
# total_bill    1.000000  0.675734  0.598315
# tip           0.675734  1.000000  0.489299
# size          0.598315  0.489299  1.000000

# %%
sns.heatmap(tips.corr(), annot = True, cmap = 'viridis');

# %%
sns.set_palette("pastel")
sns.set_palette("Set3")

# %%
# sns.heatmap(tips.isnull(), yticklabels=False, cbar=False, cmap='viridis');
sns.heatmap(tips.isnull(), yticklabels=False);

# %%
sns.clustermap(tips.corr(), annot=True, cmap='viridis')

# %%
sns.clustermap(tips.corr(), annot=True, cmap='Set3')

# %%
sns.FacetGrid(tips, col='smoker', row='sex').map(sns.distplot, 'total_bill');

# %%
sns.scatterplot(x=tips['total_bill'], y=tips['tip'], hue=tips['sex']);

# %%
sns.jointplot(x=tips['total_bill'], y=tips['tip'], kind='scatter');

# %%
sns.jointplot(x=tips['total_bill'], y=tips['tip'], kind = 'hex');

# %%
sns.set_palette("pastel")
sns.set_palette("Set3")

# %%
sns.pairplot(tips);

# %%
sns.regplot(x='tip', y='total_bill', data=tips);

# %%
sns.color_palette("husl", 9)
sns.set_palette("husl")

# %%
sns.lmplot(x='tip', y='total_bill', data=tips, hue='sex');

# %%
sns.set_palette("pastel")
sns.stripplot(x="day", y="total_bill", hue='sex', data=tips);

# %% [markdown]
# ## cake dataset

# %%
data("cake", show_doc=True)
# Out:
# cake
#
# PyDataset Documentation (adopted from R Documentation. The displayed examples are in R)
#
# ## Breakage Angle of Chocolate Cakes
#
# ### Description
#
# Data on the breakage angle of chocolate cakes made with three different
# recipes and baked at six different temperatures. This is a split-plot design
# with the recipes being whole-units and the different temperatures being
# applied to sub-units (within replicates). The experimental notes suggest that
# the replicate numbering represents temporal ordering.
#
# ### Format
#
# A data frame with 270 observations on the following 5 variables.
#
# `replicate`
#
# a factor with levels `1` to `15`
#
# `recipe`
#
# a factor with levels `A`, `B` and `C`
#
# `temperature`
#
# an ordered factor with levels `175` < `185` < `195` < `205` < `215` < `225`
#
# `angle`
#
# a numeric vector giving the angle at which the cake broke.
#
# `temp`
#
# numeric value of the baking temperature (degrees F).
#
# ### Details
#
# ...

# %%
cake = data("cake")
print(cake)
# Out:
#      replicate recipe  temperature  angle  temp
# 1            1      A          175     42   175
# 2            1      A          185     46   185
# 3            1      A          195     47   195
# 4            1      A          205     39   205
# 5            1      A          215     53   215
# ..         ...    ...          ...    ...   ...
# 266         15      C          185     28   185
# 267         15      C          195     25   195
# 268         15      C          205     25   205
# 269         15      C          215     31   215
# 270         15      C          225     25   225
#
# [270 rows x 5 columns]

# %%
iris = data('iris')
iris.head()
# Out:
#    Sepal.Length  Sepal.Width  Petal.Length  Petal.Width Species
# 1           5.1          3.5           1.4          0.2  setosa
# 2           4.9          3.0           1.4          0.2  setosa
# 3           4.7          3.2           1.3          0.2  setosa
# 4           4.6          3.1           1.5          0.2  setosa
# 5           5.0          3.6           1.4          0.2  setosa

# %%
sns.scatterplot(x='Sepal.Length', y='Sepal.Width', hue='Species', data=iris);

# %%
sns.scatterplot(x='Petal.Length', y='Petal.Width', hue='Species', data=iris);

# %%
sns.stripplot(y='Petal.Width', x='Species', data=iris);

# %%
sns.stripplot(y='Petal.Length', x='Species', data=iris);

# %%
sns.stripplot(y='Sepal.Width', x='Species', data=iris);

# %%
sns.stripplot(y='Sepal.Length', x='Species', data=iris);

# %%
sns.pairplot(iris, hue="Species");

# %%
sns.distplot(iris[iris.Species != "setosa"]["Petal.Length"], hist=True, rug=True, label="setosa")
sns.distplot(iris[iris.Species == "setosa"]["Petal length (cm)"], hist=True, rug=True, label="others")
plt.legend()
plt.show()
