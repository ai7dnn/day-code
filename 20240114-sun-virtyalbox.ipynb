# %% [markdown]
# # Virtual box 설치

# %% [markdown]
# - [Virtualbox download](https://www.virtualbox.org/wiki/Downloads)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)
# ![image-3.png](attachment:image-3.png)

# %% [markdown]
# ![image.png](attachment:image.png)
#
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# # ubuntu 설치
# > [우분투 데스크탑 버전](https://ubuntu.com/download/desktop)
# > ![image.png](attachment:image.png)
# > ![image-2.png](attachment:image-2.png)
# > ![image-3.png](attachment:image-3.png)
# > ![image-4.png](attachment:image-4.png)

# %% [markdown]
# ```
# $ cd
# $ ip addr
# $ hostname
# $ sudo vi /etc/hostname
# $ sudo vi /etc/hosts
# ![image.png](attachment:image.png)
#
# $ ping -c 3 8.8.8.8
# $ sudo passwd root
# $ su - root
#
# $# systemctl set-default multi-user.target # 텍스트 모드로 부팅
# 나중에 연습 아래로...
#
# $# systemctl set-default graphical.target # 그래픽 모드로 부팅
#
# $# apt-get uapdate
# $# apt-get install -y openssh-server curl vim tree
# $# systemctl status sshd
# $# ssh hskang@localhost
#
# yes 암호입력
#
# ```

# %% [markdown]
# - sshd에 접속
#
# ](attachment:image.png)
